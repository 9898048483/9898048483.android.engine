# %%
# %%bash
# # 1. Install System Build Dependencies
# sudo apt-get update -qq
# sudo apt-get install -y -qq build-essential ccache git libffi-dev libssl-dev libtinfo6 zip unzip zlib1g-dev openjdk-17-jdk
# pip install --upgrade pip
# pip install buildozer cython

# %%
# %%bash
# # 2. Build the APK
# cd android-client
# buildozer -v android debug

# %%
from google.colab import files
import glob
# 3. Trigger Download
apk_files = glob.glob('android-client/bin/*.apk')
if apk_files:
    files.download(apk_files[0])
else:
    print('APK build failed or not found.')
